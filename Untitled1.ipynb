# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
data=pd.read_csv("airquality.csv",index_col=0)
data
# Out:
#     date_local            state_name           county_name      city_name  \
# 0     1/1/2018               Arizona              Maricopa        Buckeye
# 1     1/1/2018                  Ohio               Belmont      Shadyside
# 2     1/1/2018               Wyoming                 Teton  Not in a city
# 3     1/1/2018          Pennsylvania          Philadelphia   Philadelphia
# 4     1/1/2018                  Iowa                  Polk     Des Moines
# ..         ...                   ...                   ...            ...
# 255   1/1/2018  District Of Columbia  District of Columbia     Washington
# 256   1/1/2018             Wisconsin                 Dodge       Kekoskee
# 257   1/1/2018              Kentucky             Jefferson     Louisville
# 258   1/1/2018              Nebraska               Douglas          Omaha
# 259   1/1/2018        North Carolina                  Wake  Not in a city
#
#                                        local_site_name   parameter_name  \
# ...

# %%
data.describe()
# Out:
#        arithmetic_mean         aqi
# count       260.000000  260.000000
# mean          0.403169    6.757692
# std           0.317902    7.061707
# min           0.000000    0.000000
# 25%           0.200000    2.000000
# 50%           0.276315    5.000000
# 75%           0.516009    9.000000
# max           1.921053   50.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 0 to 259
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_local        260 non-null    object
#  1   state_name        260 non-null    object
#  2   county_name       260 non-null    object
#  3   city_name         260 non-null    object
#  4   local_site_name   257 non-null    object
#  5   parameter_name    260 non-null    object
#  6   units_of_measure  260 non-null    object
#  7   arithmetic_mean   260 non-null    float64
#  8   aqi               260 non-null    int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 20.3+ KB

# %%
state22=data[data["county_name"]=="Los Angeles"]

# %%
state22
# Out:
#     date_local  state_name  county_name         city_name  \
# 33    1/1/2018  California  Los Angeles         Lancaster
# 42    1/1/2018  California  Los Angeles     Santa Clarita
# 61    1/1/2018  California  Los Angeles          Pasadena
# 76    1/1/2018  California  Los Angeles       Los Angeles
# 109   1/1/2018  California  Los Angeles       Los Angeles
# 110   1/1/2018  California  Los Angeles       Los Angeles
# 119   1/1/2018  California  Los Angeles            Reseda
# 132   1/1/2018  California  Los Angeles           Compton
# 163   1/1/2018  California  Los Angeles             Azusa
# 172   1/1/2018  California  Los Angeles       Pico Rivera
# 177   1/1/2018  California  Los Angeles        Long Beach
# 189   1/1/2018  California  Los Angeles            Pomona
# 233   1/1/2018  California  Los Angeles          Glendora
# 250   1/1/2018  California  Los Angeles  West Los Angeles
#
#                    local_site_name   parameter_name   units_of_measure  \
# ...

# %%
state22_other=data[(data["state_name"]=="California") & (data["county_name"]!="Los Angeles")]
state22_other
# Out:
#     date_local  state_name     county_name                  city_name  \
# 16    1/1/2018  California  San Bernardino                    Ontario
# 18    1/1/2018  California      Sacramento               Arden-Arcade
# 26    1/1/2018  California          Orange                   La Habra
# 27    1/1/2018  California         Alameda              Not in a city
# 34    1/1/2018  California          Fresno                     Fresno
# 40    1/1/2018  California       San Mateo               Redwood City
# 43    1/1/2018  California    Contra Costa                    Concord
# 45    1/1/2018  California           Butte                      Chico
# 46    1/1/2018  California       Riverside                  Mira Loma
# 58    1/1/2018  California            Kern                      Arvin
# 62    1/1/2018  California         Alameda                    Oakland
# 63    1/1/2018  California      Sacramento              Not in a city
# ...

# %%
Sampled_state22=state22.sample(n=20,replace=True,random_state=13490)
Sampled_state22
# Out:
#     date_local  state_name  county_name         city_name  \
# 109   1/1/2018  California  Los Angeles       Los Angeles
# 33    1/1/2018  California  Los Angeles         Lancaster
# 76    1/1/2018  California  Los Angeles       Los Angeles
# 233   1/1/2018  California  Los Angeles          Glendora
# 76    1/1/2018  California  Los Angeles       Los Angeles
# 177   1/1/2018  California  Los Angeles        Long Beach
# 42    1/1/2018  California  Los Angeles     Santa Clarita
# 163   1/1/2018  California  Los Angeles             Azusa
# 189   1/1/2018  California  Los Angeles            Pomona
# 177   1/1/2018  California  Los Angeles        Long Beach
# 172   1/1/2018  California  Los Angeles       Pico Rivera
# 250   1/1/2018  California  Los Angeles  West Los Angeles
# 76    1/1/2018  California  Los Angeles       Los Angeles
# 189   1/1/2018  California  Los Angeles            Pomona
# 33    1/1/2018  California  Los Angeles         Lancaster
# ...

# %%
Sampledstate22_other2=state22_other.sample(n=20,replace=True,random_state=13490)
Sampledstate22_other2
# Out:
#     date_local  state_name     county_name      city_name  \
# 198   1/1/2018  California       Riverside   Palm Springs
# 230   1/1/2018  California        Monterey        Salinas
# 27    1/1/2018  California         Alameda  Not in a city
# 27    1/1/2018  California         Alameda  Not in a city
# 227   1/1/2018  California   Santa Barbara         Lompoc
# 236   1/1/2018  California          Solano        Vallejo
# 141   1/1/2018  California   San Francisco  San Francisco
# 151   1/1/2018  California          Orange        Anaheim
# 170   1/1/2018  California       San Diego      San Diego
# 211   1/1/2018  California          Fresno  Not in a city
# 224   1/1/2018  California      Sacramento     Sacramento
# 117   1/1/2018  California       San Diego       El Cajon
# 63    1/1/2018  California      Sacramento  Not in a city
# 171   1/1/2018  California            Inyo  Not in a city
# 170   1/1/2018  California       San Diego      San Diego
# ...

# %%
Sampled_state22["aqi"].mean()
# Out:
# 17.1

# %%
Sampledstate22_other2["aqi"].mean()
# Out:
# 9.35

# %%
stats.ttest_ind(a=Sampled_state22["aqi"],b=Sampledstate22_other2["aqi"],equal_var=False)
# Out:
# TtestResult(statistic=3.232454253479157, pvalue=0.0032102155698069015, df=27.168168535581486)

# %%
ny=data[data["state_name"]=="New York"]
ny
# Out:
#     date_local state_name county_name      city_name  \
# 90    1/1/2018   New York        Erie    Cheektowaga
# 113   1/1/2018   New York       Bronx       New York
# 124   1/1/2018   New York      Monroe      Rochester
# 167   1/1/2018   New York    New York       New York
# 173   1/1/2018   New York      Queens       New York
# 182   1/1/2018   New York      Queens       New York
# 184   1/1/2018   New York     Steuben  Not in a city
# 195   1/1/2018   New York        Erie        Buffalo
# 196   1/1/2018   New York      Monroe      Rochester
# 234   1/1/2018   New York      Albany         Albany
#
#               local_site_name   parameter_name   units_of_measure  \
# 90          Buffalo Near-Road  Carbon monoxide  Parts per million
# 113           PFIZER LAB SITE  Carbon monoxide  Parts per million
# 124               ROCHESTER 2  Carbon monoxide  Parts per million
# 167                      CCNY  Carbon monoxide  Parts per million
# ...

# %%
ohio=data[data["state_name"]=="Ohio"]
ohio
# Out:
#     date_local state_name county_name             city_name  \
# 1     1/1/2018       Ohio     Belmont             Shadyside
# 12    1/1/2018       Ohio    Hamilton            Cincinnati
# 22    1/1/2018       Ohio       Stark                Canton
# 51    1/1/2018       Ohio      Summit                 Akron
# 59    1/1/2018       Ohio    Cuyahoga             Cleveland
# 120   1/1/2018       Ohio    Cuyahoga             Cleveland
# 149   1/1/2018       Ohio    Franklin              Columbus
# 191   1/1/2018       Ohio    Franklin              Columbus
# 215   1/1/2018       Ohio    Cuyahoga  Warrensville Heights
# 231   1/1/2018       Ohio  Montgomery                Dayton
# 241   1/1/2018       Ohio      Preble             New Paris
# 252   1/1/2018       Ohio    Hamilton            Cincinnati
#
#           local_site_name   parameter_name   units_of_measure  \
# 1               Shadyside  Carbon monoxide  Parts per million
# ...

# %%
stats.ttest_ind(a=ny["aqi"],b=ohio["aqi"],alternative="less",equal_var=False)
# Out:
# TtestResult(statistic=-2.025951038880333, pvalue=0.03044650269193468, df=15.036745051598716)

# %%
data.head(30)
# Out:
#    date_local    state_name     county_name      city_name  \
# 0    1/1/2018       Arizona        Maricopa        Buckeye
# 1    1/1/2018          Ohio         Belmont      Shadyside
# 2    1/1/2018       Wyoming           Teton  Not in a city
# 3    1/1/2018  Pennsylvania    Philadelphia   Philadelphia
# 4    1/1/2018          Iowa            Polk     Des Moines
# 5    1/1/2018        Hawaii        Honolulu  Not in a city
# 6    1/1/2018        Hawaii        Honolulu  Not in a city
# 7    1/1/2018  Pennsylvania            Erie           Erie
# 8    1/1/2018        Hawaii        Honolulu       Honolulu
# 9    1/1/2018      Colorado         Larimer   Fort Collins
# 10   1/1/2018     Minnesota          Dakota      Rosemount
# 11   1/1/2018       Indiana          Marion   Indianapolis
# 12   1/1/2018          Ohio        Hamilton     Cincinnati
# 13   1/1/2018       Arizona        Maricopa           Mesa
# 14   1/1/2018      Missouri         Jackson    Kansas City
# ...

# %%
sampled_data=data.sample(n=50,replace=True,random_state=31208)
sampled_data
# Out:
#     date_local      state_name            county_name  \
# 103   1/1/2018        Kentucky              Jefferson
# 210   1/1/2018         Arizona                   Pima
# 181   1/1/2018   New Hampshire             Rockingham
# 248   1/1/2018        Michigan                  Wayne
# 252   1/1/2018            Ohio               Hamilton
# 10    1/1/2018       Minnesota                 Dakota
# 126   1/1/2018         Florida                Broward
# 142   1/1/2018        Colorado                 Denver
# 221   1/1/2018  South Carolina               Richland
# 84    1/1/2018        Kentucky               Edmonson
# 254   1/1/2018         Arizona                   Pima
# 256   1/1/2018       Wisconsin                  Dodge
# 247   1/1/2018           Texas                 Dallas
# 239   1/1/2018      California                Alameda
# 177   1/1/2018      California            Los Angeles
# 163   1/1/2018      California            Los Angeles
# ...

# %%
estimate_standared_error=sampled_data["aqi"].std() /np.sqrt(sampled_data.shape[0])
estimate_standared_error
# Out:
# 0.7020029652824168

# %%
mean_sample_means=sampled_data["aqi"].mean()
mean_sample_means
# Out:
# 5.82

# %%
# Use the correct argument name for your version of scipy
confidence_level = 0.95
confidence_interval = stats.norm.interval(confidence=confidence_level, loc=mean_sample_means, scale=estimate_standared_error)

(confidence_interval)
# Out:
# (4.444099471006141, 7.195900528993859)

# %%
# Add a new column based on the condition
sampled_data1 = sampled_data[(sampled_data['aqi'] > 7.195) | (sampled_data['aqi'] < 4.444)]

sampled_data1
# Out:
#     date_local      state_name            county_name  \
# 103   1/1/2018        Kentucky              Jefferson
# 181   1/1/2018   New Hampshire             Rockingham
# 248   1/1/2018        Michigan                  Wayne
# 252   1/1/2018            Ohio               Hamilton
# 10    1/1/2018       Minnesota                 Dakota
# 221   1/1/2018  South Carolina               Richland
# 84    1/1/2018        Kentucky               Edmonson
# 254   1/1/2018         Arizona                   Pima
# 256   1/1/2018       Wisconsin                  Dodge
# 247   1/1/2018           Texas                 Dallas
# 239   1/1/2018      California                Alameda
# 177   1/1/2018      California            Los Angeles
# 163   1/1/2018      California            Los Angeles
# 12    1/1/2018            Ohio               Hamilton
# 36    1/1/2018   Massachusetts                Suffolk
# 191   1/1/2018            Ohio               Franklin
# ...

# %%
sampled_data2 = sampled_data1[(sampled_data1['aqi'] > 7.1195)]
sampled_data2
# Out:
#     date_local  state_name            county_name      city_name  \
# 248   1/1/2018    Michigan                  Wayne        Detroit
# 254   1/1/2018     Arizona                   Pima         Tucson
# 239   1/1/2018  California                Alameda        Oakland
# 177   1/1/2018  California            Los Angeles     Long Beach
# 163   1/1/2018  California            Los Angeles          Azusa
# 109   1/1/2018  California            Los Angeles    Los Angeles
# 207   1/1/2018    Michigan                  Wayne  Not in a city
# 76    1/1/2018  California            Los Angeles    Los Angeles
# 248   1/1/2018    Michigan                  Wayne        Detroit
# 243   1/1/2018      Alaska  Fairbanks North Star       Fairbanks
# 161   1/1/2018  California                   Kern    Bakersfield
# 130   1/1/2018  California         San Bernardino        Fontana
# 258   1/1/2018    Nebraska                Douglas          Omaha
#
# ...

# %%
sampled_data3 = sampled_data1[(sampled_data1['aqi'] < 4.44)]
sampled_data3
# Out:
#     date_local      state_name   county_name                 city_name  \
# 103   1/1/2018        Kentucky     Jefferson                Louisville
# 181   1/1/2018   New Hampshire    Rockingham               Londonderry
# 252   1/1/2018            Ohio      Hamilton                Cincinnati
# 10    1/1/2018       Minnesota        Dakota                 Rosemount
# 221   1/1/2018  South Carolina      Richland        Dentsville (Dents)
# 84    1/1/2018        Kentucky      Edmonson             Not in a city
# 256   1/1/2018       Wisconsin         Dodge                  Kekoskee
# 247   1/1/2018           Texas        Dallas                    Dallas
# 12    1/1/2018            Ohio      Hamilton                Cincinnati
# 36    1/1/2018   Massachusetts       Suffolk                    Boston
# 191   1/1/2018            Ohio      Franklin                  Columbus
# 184   1/1/2018        New York       Steuben             Not in a city
# ...

# %%
# Print the specified columns: state_name, county_name, and aqi
sampled_data2[['state_name', 'county_name', 'aqi']]
# Out:
#      state_name            county_name  aqi
# 248    Michigan                  Wayne    8
# 254     Arizona                   Pima   14
# 239  California                Alameda   15
# 177  California            Los Angeles   24
# 163  California            Los Angeles   10
# 109  California            Los Angeles   17
# 207    Michigan                  Wayne   10
# 76   California            Los Angeles   17
# 248    Michigan                  Wayne    8
# 243      Alaska  Fairbanks North Star     8
# 161  California                   Kern   13
# 130  California         San Bernardino   11
# 258    Nebraska                Douglas    9

# %%
# Assuming sampled_data2 is already defined and contains the necessary columns
# Ensure to reset the index for a cleaner plot
sampled_data2.reset_index(drop=True, inplace=True)

# Generate a color for each bar (you can customize this palette)
colors = plt.cm.viridis(np.linspace(0, 1, len(sampled_data2)))

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sampled_data2['state_name'], sampled_data2['aqi'], color=colors)

# Adding titles and labels
plt.title('AQI by State')
plt.xlabel('State Name')
plt.ylabel('AQI')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.grid(axis='y')

# Save the plot as PNG and show it
plt.tight_layout()
plt.savefig("AQI.png")
plt.show()

# %%
# Print the specified columns: state_name, county_name, and aqi
sampled_data3[['state_name', 'county_name', 'aqi']]
# Out:
#          state_name   county_name  aqi
# 103        Kentucky     Jefferson    2
# 181   New Hampshire    Rockingham    2
# 252            Ohio      Hamilton    3
# 10        Minnesota        Dakota    3
# 221  South Carolina      Richland    1
# 84         Kentucky      Edmonson    2
# 256       Wisconsin         Dodge    2
# 247           Texas        Dallas    2
# 12             Ohio      Hamilton    3
# 36    Massachusetts       Suffolk    3
# 191            Ohio      Franklin    2
# 184        New York       Steuben    2
# 182        New York        Queens    2
# 145   Massachusetts       Suffolk    2
# 103        Kentucky     Jefferson    2
# 54   North Carolina   Mecklenburg    2
# 79     Pennsylvania  Philadelphia    3
# 83            Texas     Jefferson    2
# 68          Indiana        Marion    3
# 118         Wyoming      Converse    1
# 49        Tennessee        Shelby    1
# 24            Texas        Harris    3
# 60             Iowa         Scott    2
# ...

# %%
# Assuming sampled_data3 is already defined and contains the necessary columns
# Ensure to reset the index for a cleaner plot
sampled_data3.reset_index(drop=True, inplace=True)

# Generate a color for each bar using a colormap
colors = plt.cm.tab20(np.linspace(0, 1, len(sampled_data3)))  # Tab20 colormap for distinct colors

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sampled_data3['state_name'], sampled_data3['aqi'], color=colors)

# Adding titles and labels
plt.title('AQI by State')
plt.xlabel('State Name')
plt.ylabel('AQI')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.grid(axis='y')

# Save the plot as PNG and show it
plt.tight_layout()
plt.savefig("AQI.png")
plt.show()

# %%
# Convert 'aqi' to numeric, if needed (ignores errors for non-numeric entries)
sampled_data['aqi'] = pd.to_numeric(sampled_data['aqi'], errors='coerce')

# Now apply the condition
sampled_data = sampled_data[sampled_data['aqi'] < 4.44]

# Display the result
sampled_data
# Out:
#     date_local      state_name   county_name                 city_name  \
# 103   1/1/2018        Kentucky     Jefferson                Louisville
# 181   1/1/2018   New Hampshire    Rockingham               Londonderry
# 252   1/1/2018            Ohio      Hamilton                Cincinnati
# 10    1/1/2018       Minnesota        Dakota                 Rosemount
# 221   1/1/2018  South Carolina      Richland        Dentsville (Dents)
# 84    1/1/2018        Kentucky      Edmonson             Not in a city
# 256   1/1/2018       Wisconsin         Dodge                  Kekoskee
# 247   1/1/2018           Texas        Dallas                    Dallas
# 12    1/1/2018            Ohio      Hamilton                Cincinnati
# 36    1/1/2018   Massachusetts       Suffolk                    Boston
# 191   1/1/2018            Ohio      Franklin                  Columbus
# 184   1/1/2018        New York       Steuben             Not in a city
# ...

# %%
data.head(10)
# Out:
#   date_local    state_name   county_name      city_name  \
# 0   1/1/2018       Arizona      Maricopa        Buckeye
# 1   1/1/2018          Ohio       Belmont      Shadyside
# 2   1/1/2018       Wyoming         Teton  Not in a city
# 3   1/1/2018  Pennsylvania  Philadelphia   Philadelphia
# 4   1/1/2018          Iowa          Polk     Des Moines
# 5   1/1/2018        Hawaii      Honolulu  Not in a city
# 6   1/1/2018        Hawaii      Honolulu  Not in a city
# 7   1/1/2018  Pennsylvania          Erie           Erie
# 8   1/1/2018        Hawaii      Honolulu       Honolulu
# 9   1/1/2018      Colorado       Larimer   Fort Collins
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# 1                                          Shadyside  Carbon monoxide
# 2  Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# ...

# %%
data["aqi"].describe()
# Out:
# count    260.000000
# mean       6.757692
# std        7.061707
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        9.000000
# max       50.000000
# Name: aqi, dtype: float64

# %%
 data["state_name"].describe()
# Out:
# count            260
# unique            52
# top       California
# freq              66
# Name: state_name, dtype: object

# %%
data['aqi'].hist()
# Out:
# <Axes: >

# %%
mean=data['aqi'].mean()
mean
# Out:
# 6.757692307692308

# %%
std_dev=data['aqi'].std()
std_dev
# Out:
# 7.0617066788207215

# %%
lower_limit=mean-1*std_dev
upper_limit=mean+1*std_dev
((data["aqi"]>=lower_limit)&
(data["aqi"]<=upper_limit)).mean()
# Out:
# 0.8730769230769231

# %%
lower_limit=mean-2*std_dev
upper_limit=mean+2*std_dev
((data["aqi"]>=lower_limit)&
(data["aqi"]<=upper_limit)).mean()
# Out:
# 0.9576923076923077

# %%
lower_limit=mean-3*std_dev
upper_limit=mean+3*std_dev
((data["aqi"]>=lower_limit)&
(data["aqi"]<=upper_limit)).mean()
# Out:
# 0.9807692307692307

# %%
data["Z_Score"]=stats.zscore(data['aqi'])
data
# Out:
#     date_local            state_name           county_name      city_name  \
# 0     1/1/2018               Arizona              Maricopa        Buckeye
# 1     1/1/2018                  Ohio               Belmont      Shadyside
# 2     1/1/2018               Wyoming                 Teton  Not in a city
# 3     1/1/2018          Pennsylvania          Philadelphia   Philadelphia
# 4     1/1/2018                  Iowa                  Polk     Des Moines
# ..         ...                   ...                   ...            ...
# 255   1/1/2018  District Of Columbia  District of Columbia     Washington
# 256   1/1/2018             Wisconsin                 Dodge       Kekoskee
# 257   1/1/2018              Kentucky             Jefferson     Louisville
# 258   1/1/2018              Nebraska               Douglas          Omaha
# 259   1/1/2018        North Carolina                  Wake  Not in a city
#
#                                        local_site_name   parameter_name  \
# ...

# %%
data[(data['Z_Score'] > 3) |(data['Z_Score'] <-3)]
data
# Out:
#     date_local            state_name           county_name      city_name  \
# 0     1/1/2018               Arizona              Maricopa        Buckeye
# 1     1/1/2018                  Ohio               Belmont      Shadyside
# 2     1/1/2018               Wyoming                 Teton  Not in a city
# 3     1/1/2018          Pennsylvania          Philadelphia   Philadelphia
# 4     1/1/2018                  Iowa                  Polk     Des Moines
# ..         ...                   ...                   ...            ...
# 255   1/1/2018  District Of Columbia  District of Columbia     Washington
# 256   1/1/2018             Wisconsin                 Dodge       Kekoskee
# 257   1/1/2018              Kentucky             Jefferson     Louisville
# 258   1/1/2018              Nebraska               Douglas          Omaha
# 259   1/1/2018        North Carolina                  Wake  Not in a city
#
#                                        local_site_name   parameter_name  \
# ...

# %%
# Assuming 'data' is your DataFrame and it contains 'state_name' and 'Z_Score' columns
# Filtering the data based on the Z-score condition
filtered_data = data[(data['Z_Score'] > 3) | (data['Z_Score'] < -3)]

# Plotting the filtered data as a bar graph
plt.figure(figsize=(9, 8))
plt.bar(filtered_data['state_name'], filtered_data['Z_Score'], color='grey')

# Adding titles and labels
plt.title('Z-Scores Greater than 3 or Less than -3')
plt.xlabel('State Name')
plt.ylabel('Z Score')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.savefig("Z_Score_Filtered_Bar.png")
plt.show()
